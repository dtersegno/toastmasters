# %% [markdown]
# Toastmasters Scheduling
# ---
#
# > Everyone has to do a prepared, impromptu, and evaluation speech (3 speeches on different dates)
# There are four leadership roles (president, toastmaster, table topics master, and general evaluator) --at least once but some may have two (but preferably not BOTH Presiident and Table Topics Master).
#
# > could you make it so that a single person does NOT get BOTH President and Toastmaster roles.
#
#
# The restrictions are:
# - everyone has to do each of the three "main" jobs once
# - the three main jobs are repeated 2 or 3 times on a single day
# - students should speak "against" a different set of speakers between their two times
# - auxiliary jobs should be filled with remaining students, with preference to students who haven't done that job yet
#
# > Is "the same person shouldn't get president and toastmaster roles" over the course of the entire process, or just during a single day? over the course of the entire process.
#
# > There should also be a "stand-in" person but not all days have a "stand-in" because on some days there will be 4 impromptu speeches or 4 prepared AND 4 evaluation speeches
#
# > So stand-ins usually happen on days where there are no extra speakers (three speakers per day)
#
# > 7 days
#
# > But 23 students is a lot

# %%
import numpy as np
import pandas as pd

# %%
num_days = 7
num_students = 23

students = 'abcdefghijklmnopqrstuvwxyz'[:num_students]

speaker_roles = ['Prepared Speaker',
                'Impromptu Speaker',
                'Evaluator'
]

prepared_speakers = ['Prepared Speaker 1',
                     'Prepared Speaker 2',
                     'Prepared Speaker 3'
]

evaluators = [
    'Evaluator 1',
    'Evaluator 2',
    'Evaluator 3'
]

impromptu_speakers = [
    'Impromptu Speaker 1',
    'Impromptu Speaker 2',
    'Impromptu Speaker 3'    
]

speakers = ['Prepared Speaker 1',
           'Impromptu Speaker 1',
           'Evaluator 1',
            'Prepared Speaker 2',
            'Impromptu Speaker 2',
            'Evaluator 2',
            'Prepared Speaker 3',
            'Impromptu Speaker 3',
            'Evaluator 3'
]

leaders = [
            'Toastmaster',
            'President',
            'Table Topics Master',
            'General Evaluator'
]

auxiliary = ['Greeter',
            'Joke Master',
            'Timer',
            'Grammarian',
            'Word of the Day',
            'Ah Counter',
            'Ballot Counter',
            'Thought of the day',
            'Sergeant at arms',
            'Stand-in'
]

# %%
# Out:
#     Prepared Speaker 1 Impromptu Speaker 1 Evaluator 1 Prepared Speaker 2  \
# day
# 0                  NaN                 NaN         NaN                NaN
# 1                  NaN                 NaN         NaN                NaN
# 2                  NaN                 NaN         NaN                NaN
# 3                  NaN                 NaN         NaN                NaN
# 4                  NaN                 NaN         NaN                NaN
# 5                  NaN                 NaN         NaN                NaN
# 6                  NaN                 NaN         NaN                NaN
#
#     Impromptu Speaker 2 Evaluator 2 Prepared Speaker 3 Impromptu Speaker 3  \
# day
# 0                   NaN         NaN                NaN                 NaN
# 1                   NaN         NaN                NaN                 NaN
# 2                   NaN         NaN                NaN                 NaN
# 3                   NaN         NaN                NaN                 NaN
# 4                   NaN         NaN                NaN                 NaN
# 5                   NaN         NaN                NaN                 NaN
# 6                   NaN         NaN                NaN                 NaN
#
#     Evaluator 3 Toastmaster  ... Greeter Joke Master Timer Grammarian  \
# day                          ...
# 0           NaN         NaN  ...     NaN         NaN   NaN        NaN
# 1           NaN         NaN  ...     NaN         NaN   NaN        NaN
# 2           NaN         NaN  ...     NaN         NaN   NaN        NaN
# 3           NaN         NaN  ...     NaN         NaN   NaN        NaN
# 4           NaN         NaN  ...     NaN         NaN   NaN        NaN
# 5           NaN         NaN  ...     NaN         NaN   NaN        NaN
# 6           NaN         NaN  ...     NaN         NaN   NaN        NaN
#
#     Word of the Day Ah Counter Ballot Counter Thought of the day  \
# day
# 0               NaN        NaN            NaN                NaN
# 1               NaN        NaN            NaN                NaN
# 2               NaN        NaN            NaN                NaN
# 3               NaN        NaN            NaN                NaN
# 4               NaN        NaN            NaN                NaN
# 5               NaN        NaN            NaN                NaN
# 6               NaN        NaN            NaN                NaN
#
#     Sergeant at arms Stand-in
# day
# 0                NaN      NaN
# 1                NaN      NaN
# 2                NaN      NaN
# 3                NaN      NaN
# 4                NaN      NaN
# 5                NaN      NaN
# 6                NaN      NaN
#
# [7 rows x 23 columns]

# %% [markdown]
# Constraints:
# - Everyone has to do each of the three types of speeches once and only once
# - Everyone should do one of the four leadership roles once.
#     - repeats should preferentially be General Evaluator
# - Everyone has one and only one job per day
# - Those who do not have a speech or a leadership role fill in one of the auxiliary roles.

# %%
#everyone has to do each of the three types of speeches once and only once

# returns True if there are no repeat assignments for the given jobs.
# people can do multiple jobs, but not not the same job twice
def check_job_repeats(calendar, jobs = []):
    #check all columns if none given
    if len(jobs) == 0:
        jobs = calendar.columns
    result = True
    for job in jobs:
        if calendar[job].duplicated().sum() > 0:
            result = False
        if not result:
            break
    return result


# nobody should have more than one job a day

# Checks if all the jobs on all the days of a dataframe are uniquely assigned --- no person has more than 1 job.
# returns True if so.
def check_day_repeats(calendar, days = []):
    if len(days) == 0:
        days = calendar.index
    result = True
    for row in days:
        if calendar.loc[row].duplicated().sum() > 0:
            result = False
        if not result:
            break
    return result

#returns true if there are no duplicates in the entire collection of job_list
def check_job_type_repeats(calendar, job_list, up_to_day):
    these_values = calendar.loc[:up_to_day, job_list].values.flatten()
    #print(these_values)
    try:
        u, c = np.unique(these_values, return_counts=True)
    except:
        print(f'Had a problem with these values:')
        print(these_values.reshape(-1,len(job_list)))
    dup = u[c > 1]
    return len(dup) == 0

# %% [markdown]
# Using [this stack overflow answer](https://stackoverflow.com/questions/11528078/determining-duplicate-values-in-an-array) to help with finding duplicates in the flattened numpy array.

# %%
check_job_type_repeats(cal, speakers, 1)
# Out:
# ['k' 'v' 's' 'd' 'r' 'c' 's' 'u' 's' 'm' 'r' 's' 'o' 'e' 'f' 'q' 'm' 'f']
# True

# %%
cal
# Out:
#     Prepared Speaker 1 Impromptu Speaker 1 Evaluator 1 Prepared Speaker 2  \
# day
# 0                    k                   v           s                  d
# 1                    m                   r           s                  o
# 2                    b                   d           t                  h
# 3                    b                   k           v                  g
# 4                    c                   g           a                  m
# 5                    n                   w         NaN                NaN
# 6                  NaN                 NaN         NaN                NaN
#
#     Impromptu Speaker 2 Evaluator 2 Prepared Speaker 3 Impromptu Speaker 3  \
# day
# 0                     r           c                  s                   u
# 1                     e           f                  q                   m
# 2                     q           t                  n                   s
# 3                     n           u                  b                   p
# 4                     u           d                  f                   m
# 5                   NaN         NaN                NaN                 NaN
# 6                   NaN         NaN                NaN                 NaN
#
#     Evaluator 3 Toastmaster  ... Greeter Joke Master Timer Grammarian  \
# day                          ...
# 0             s           f  ...       k           l     w          h
# 1             f           u  ...       g           l     j          t
# 2             n           f  ...       d           o     q          u
# 3             r           t  ...       d           f     t          d
# 4             f           r  ...       d           p     u          l
# 5           NaN         NaN  ...     NaN         NaN   NaN        NaN
# 6           NaN         NaN  ...     NaN         NaN   NaN        NaN
#
#     Word of the Day Ah Counter Ballot Counter Thought of the day  \
# day
# 0                 h          m              q                  v
# 1                 i          q              i                  s
# 2                 n          i              t                  h
# 3                 o          q              q                  q
# 4                 m          e              e                  m
# 5               NaN        NaN            NaN                NaN
# 6               NaN        NaN            NaN                NaN
#
#     Sergeant at arms Stand-in
# day
# 0                  d        h
# 1                  b        l
# 2                  b        v
# 3                  r        v
# 4                  u        m
# 5                NaN      NaN
# 6                NaN      NaN
#
# [7 rows x 23 columns]

# %%
cal[speakers].values.flatten()
# Out:
# array(['k', 'v', 's', 'd', 'r', 'c', 's', 'u', 's', 'm', 'r', 's', 'o',
#        'e', 'f', 'q', 'm', 'f', 'b', 'd', 't', 'h', 'q', 't', 'n', 's',
#        'n', 'b', 'k', 'v', 'g', 'n', 'u', 'b', 'p', 'r', 'c', 'g', 'a',
#        'm', 'u', 'd', 'f', 'm', 'f', 'n', 'w', nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#       dtype=object)

# %% [markdown]
# Create a list of students to keep track of for each job. Each list

# %% [markdown]
# Randomly assign students to the first set of jobs. For each job, remove that student from its acceptable list.
#
# Randomly assign students to successive days of jobs. These could be placed together, or one at a time. Check if the student  has done the jobs before If an auxiliary job's list is empty, refill it with student names.

# %% [markdown]
# When using random, make sure to follow the [numpy best practice](https://numpy.org/doc/stable/reference/random/index.html) by creating an instance of a random number generator, rather than the legacy `seed()`.

# %%
cal = pd.DataFrame(columns = speakers + leaders + auxiliary, index = range(num_days))
cal.index.rename('day', inplace=True)

# create dicts of the students for each day and for each job.
# allowed students by day
full_student_list = [
        char for char in students
]

student_buckets_by_day = {
    day:full_student_list
    for day in cal.index
}
#allowed students by role
student_buckets_by_role = {
    role:full_student_list
    for role in speakers + leaders + auxiliary
}

#make an rng
seed = 2022
rng = np.random.default_rng(seed)
day_fill_counter_max = 1000
verbose = False


#for each day,
for day in cal.index:
   
    #say which day is being filled.
    print(f'filling schedule for day {day}.')
    #repeat the day's placement until it's right.
    day_fill_counter = 0
    day_filled = False
    while day_filled and day_fill_counter < day_fill_counter_max:
        day_fill_counter += 1
        #refill availability bucket
        student_buckets_by_day[day] = full_student_list
        #for each role in the day,
        for role in cal.columns:
            #get the allowed students to be filled in that role
            allowed_students = np.intersect1d(student_buckets_by_day[day], student_buckets_by_role[role])
            #if that length is too short, report it and bail on filling this day.
            if len(allowed_students) == 0:
                print(f'No more allowed students found for day {day}, role {role}.')
                break
            else:
                #pick out a student
                this_student = rng.choice(allowed_students)
                #remove the student from the day bucket
                student_buckets_by_day[day].remove(this_student)
                #assign them that role
                cal.loc[day, role] = this_student
        #after filling all the roles, check if they satisfy the rules
        #if they do, remove the students from their respective role buckets
        #say we found the
# Out:
# filling schedule for day 0.
# filling schedule for day 1.
# filling schedule for day 2.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8600/2902491065.py in <module>
#      38             counter_students += 1
#      39             #place a random student from the intersection of the role's student list and the day's list in the slot
# ---> 40             allowed_students = np.intersect1d(student_buckets_by_day[day], student_buckets_by_role[role])
#      41             if len(allowed_students) == 0:
#      42                 print(f'No more allowed students found for day {day}, role {role}.')
#
# <__array_function__ internals> in intersect1d(*args, **kwargs)
#
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\lib\arraysetops.py in intersect1d(ar1, ar2, assume_unique, return_indices)
#     417             ar2, ind2 = unique(ar2, return_index=True)
#     418         else:
# --> 419             ar1 = unique(ar1)
#     420             ar2 = unique(ar2)
#     421     else:
#
# <__array_function__ internals> in unique(*args, **kwargs)
#
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\lib\arraysetops.py in unique(ar, return_index, return_inverse, return_counts, axis)
#     260     ar = np.asanyarray(ar)
#     261     if axis is None:
# --> 262         ret = _unique1d(ar, return_index, return_inverse, return_counts)
#     263         return _unpack_tuple(ret)
#     264
#
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\lib\arraysetops.py in _unique1d(ar, return_index, return_inverse, return_counts)
#     321         aux = ar[perm]
#     322     else:
# --> 323         ar.sort()
#     324         aux = ar
#     325     mask = np.empty(aux.shape, dtype=np.bool_)
#
# KeyboardInterrupt:

# %%
cal
# Out:
#     Prepared Speaker 1 Impromptu Speaker 1 Evaluator 1 Prepared Speaker 2  \
# day
# 0                    k                   v           s                  d
# 1                    m                   r           s                  o
# 2                    b                   d           t                  h
# 3                    b                   k           v                  g
# 4                    c                   g           a                  m
# 5                    n                   l           o                  b
# 6                    k                   g           o                  o
#
#     Impromptu Speaker 2 Evaluator 2 Prepared Speaker 3 Impromptu Speaker 3  \
# day
# 0                     r           c                  s                   u
# 1                     e           f                  q                   m
# 2                     q           t                  n                   s
# 3                     n           u                  b                   p
# 4                     u           d                  f                   m
# 5                     g           t                  f                   d
# 6                     p           a                  g                   l
#
#     Evaluator 3 Toastmaster  ... Greeter Joke Master Timer Grammarian  \
# day                          ...
# 0             s           f  ...       k           l     w          h
# 1             f           u  ...       g           l     j          t
# 2             n           f  ...       d           o     q          u
# 3             r           t  ...       d           f     t          d
# 4             f           r  ...       d           p     u          l
# 5             r           e  ...       f           m     e          d
# 6             s           w  ...       q           q     d          a
#
#     Word of the Day Ah Counter Ballot Counter Thought of the day  \
# day
# 0                 h          m              q                  v
# 1                 i          q              i                  s
# 2                 n          i              t                  h
# 3                 o          q              q                  q
# 4                 m          e              e                  m
# 5                 o          t              d                  b
# 6                 m          d              s                  e
#
#     Sergeant at arms Stand-in
# day
# 0                  d        h
# 1                  b        l
# 2                  b        v
# 3                  r        v
# 4                  u        m
# 5                  i        w
# 6                  e        i
#
# [7 rows x 23 columns]

# %%
check_day_repeats(cal[:1])
# Out:
# False

# %%
check_day_repeats(cal.iloc[:0])
# Out:
# True

# %%
check_day_repeats(cal.loc[:0])
# Out:
# False

# %%
for col in cal.columns:
    print(f'{col}:{check_job_repeats(cal, jobs = [col])}')
    
for row in cal.index:
    print(f'{row}:{check_day_repeats(cal, [row])}')
# Out:
# Prepared Speaker 1:False
# Impromptu Speaker 1:True
# Evaluator 1:False
# Prepared Speaker 2:True
# Impromptu Speaker 2:False
# Evaluator 2:True
# Prepared Speaker 3:False
# Impromptu Speaker 3:True
# Evaluator 3:False
# Toastmaster:False
# President:False
# Table Topics Master:False
# General Evaluator:False
# Greeter:False
# Joke Master:False
# Timer:False
# Grammarian:False
# Word of the Day:False
# Ah Counter:True
# Ballot Counter:True
# Thought of the day:False
# Sergeant at arms:False
# Stand-in:True
# 1:False
# 2:False
# 3:False
# 4:False
# 5:False
# 6:False
# 7:False

# %%
cal[speakers]
# Out:
#     Prepared Speaker 1 Impromptu Speaker 1 Evaluator 1 Prepared Speaker 2  \
# day
# 0                    k                   v           s                  d
# 1                    m                   r           s                  o
# 2                  NaN                 NaN         NaN                NaN
# 3                  NaN                 NaN         NaN                NaN
# 4                  NaN                 NaN         NaN                NaN
# 5                  NaN                 NaN         NaN                NaN
# 6                  NaN                 NaN         NaN                NaN
#
#     Impromptu Speaker 2 Evaluator 2 Prepared Speaker 3 Impromptu Speaker 3  \
# day
# 0                     r           c                  s                   u
# 1                     e           f                  q                   m
# 2                   NaN         NaN                NaN                 NaN
# 3                   NaN         NaN                NaN                 NaN
# 4                   NaN         NaN                NaN                 NaN
# 5                   NaN         NaN                NaN                 NaN
# 6                   NaN         NaN                NaN                 NaN
#
#     Evaluator 3
# day
# 0             s
# 1             f
# 2           NaN
# 3           NaN
# 4           NaN
# 5           NaN
# 6           NaN

# %%
check_job_repeats(cal.loc[:1],speakers)
# Out:
# False

# %%
cal.loc[:1]
# Out:
#     Prepared Speaker 1 Impromptu Speaker 1 Evaluator 1 Prepared Speaker 2  \
# day
# 0                    k                   v           s                  d
# 1                    m                   r           s                  o
#
#     Impromptu Speaker 2 Evaluator 2 Prepared Speaker 3 Impromptu Speaker 3  \
# day
# 0                     r           c                  s                   u
# 1                     e           f                  q                   m
#
#     Evaluator 3 Toastmaster  ... Greeter Joke Master Timer Grammarian  \
# day                          ...
# 0             s           f  ...       k           l     w          h
# 1             f           u  ...       g           l     w        NaN
#
#     Word of the Day Ah Counter Ballot Counter Thought of the day  \
# day
# 0                 h          m              q                  s
# 1               NaN        NaN            NaN                NaN
#
#     Sergeant at arms Stand-in
# day
# 0                  d        h
# 1                NaN      NaN
#
# [2 rows x 23 columns]

# %%
cal.duplicated()
# Out:
# day
# 0    False
# 1    False
# 2    False
# 3     True
# 4     True
# 5     True
# 6     True
# dtype: bool

# %%
cal[speakers]
# Out:
#     Prepared Speaker 1 Impromptu Speaker 1 Evaluator 1 Prepared Speaker 2  \
# day
# 0                    k                   v           s                  d
# 1                    m                   r           s                  o
# 2                  NaN                 NaN         NaN                NaN
# 3                  NaN                 NaN         NaN                NaN
# 4                  NaN                 NaN         NaN                NaN
# 5                  NaN                 NaN         NaN                NaN
# 6                  NaN                 NaN         NaN                NaN
#
#     Impromptu Speaker 2 Evaluator 2 Prepared Speaker 3 Impromptu Speaker 3  \
# day
# 0                     r           c                  s                   u
# 1                     e           f                  q                   m
# 2                   NaN         NaN                NaN                 NaN
# 3                   NaN         NaN                NaN                 NaN
# 4                   NaN         NaN                NaN                 NaN
# 5                   NaN         NaN                NaN                 NaN
# 6                   NaN         NaN                NaN                 NaN
#
#     Evaluator 3
# day
# 0             s
# 1             f
# 2           NaN
# 3           NaN
# 4           NaN
# 5           NaN
# 6           NaN

# %% [markdown]
# # old code:

# %%
cal = pd.DataFrame(columns = speakers + leaders + auxiliary, index = range(num_days))
cal.index.rename('day', inplace=True)

# create dicts of the students for each day and for each job.
# allowed students by day
full_student_list = [
        char for char in students
]

student_buckets_by_day = {
    day:full_student_list
    for day in cal.index
}
#allowed students by role
student_buckets_by_role = {
    role:full_student_list
    for role in speakers + leaders + auxiliary
}

#make an rng
seed = 2022
rng = np.random.default_rng(seed)
counter_students_max = 1000
verbose = False

#for each day,
for day in cal.index:
    student_buckets_by_day[day] = full_student_list
    #say which day is being filled.
    print(f'filling schedule for day {day}.')
    #for each role,
    for role in cal.columns:
#         if len(student_buckets_by_role[role]) == 0:
#             student_buckets_by_role[role] = full_student_list
        counter_students = 0
        role_selected = False
        while counter_students < counter_students_max and not role_selected:
            counter_students += 1
            #place a random student from the intersection of the role's student list and the day's list in the slot
            allowed_students = np.intersect1d(student_buckets_by_day[day], student_buckets_by_role[role])
            if len(allowed_students) == 0:
                print(f'No more allowed students found for day {day}, role {role}.')
                break
            else: #pick out a student and assign it that role
                this_student = rng.choice(allowed_students)
                cal.loc[day, role] = this_student
            #perform column checks
            #the column with itself (repeated role)
            columns_ok = check_job_repeats(cal.loc[:day], [role])
            # ...multiple columns for speaking roles, ...
            if role == prepared_speakers[-1]:
                columns_ok = columns_ok and check_job_type_repeats(cal.loc[:day], prepared_speakers, day)
            elif role == impromptu_speakers[-1]:
                columns_ok = columns_ok and check_job_type_repeats(cal.loc[:day], impromptu_speakers, day)
            elif role == evaluators[-1]:
                columns_ok = columns_ok and check_job_type_repeats(cal.loc[:day], evaluators, day)
            # ...and leadership roles.
            elif role == leaders[-1]:
                columns_ok = columns_ok and check_job_type_repeats(cal.loc[:day], leaders, day) 
            if counter_students%(counter_students_max//10) == 0 and counter_students%(counter_students_max)//10 > 0 and verbose:
                print(f'Tried {counter_students} combinations for day {day}, {role}.')
            if counter_students == counter_students_max and counter_students%(counter_students_max)//10 > 0 and verbose:
                print(f'Reached {counter_students_max} combinations for day {day}, {role}!')
            #check that the student hasn't been placed yet today.
            row_ok = check_day_repeats(cal.loc[[day]])
            if columns_ok and row_ok:
                role_selected = True
                print(f'Decisively placed {this_student} as {role}.')
                #the student has been chosen for the day
                student_buckets_by_day[day].remove(this_student)
                #the student has been chosen for this role
                try:
                    if role in prepared_speakers:
                        for column in prepared_speakers:
                            student_buckets_by_role[column].remove(this_student)
                    elif role in impromptu_speakers:
                        for column in impromptu_speakers:
                            student_buckets_by_role[column].remove(this_student)
                    elif role in leaders:
                        for column in evaluators:
                            student_buckets_by_role[column].remove(this_student)
                    else:
                        student_buckets_by_role[role].remove(this_student)
                except:
                    print(f'Could not remove student {this_student} for role {role} from {student_buckets_by_role[role]}.')
                
        #remove the student from the day's list of choices
print('done!')
